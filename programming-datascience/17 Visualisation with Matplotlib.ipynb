# %% [markdown]
# # Visualisation with Matplotlib
#
# Matplotlib is a multi-platform data visualization library built on NumPy arrays.
#
# Dates back to 2002.
#
# Adopted as the plotting package of choice of the Space Telescope Science Institute (Hubble Telescope people). ![image.png](attachment:image.png)

# %% [markdown]
# # Why use Matplotlib?
#
# Plays well with lots of operating systems.
#
# Cross-platform approach greatest strength.
#
# Ubiquitous within scientific Python world.

# %% [markdown]
# # Drawbacks to Matplotlib?
#
# Showing its age.
#
# In R, ggplot and ggvis are a la mode.
#
# Seaborn, ggpy, Holoview, Altair and even Pandas wrap Matplotlib's API
#
# But, it's a vital piece of the data visualisation stack.

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
plt.style.use('classic')

# %% [markdown]
# ## Plotting from Jupyter Notebook
#
# Need to enable Matplotlib mode in order to use Matplotlib interactively:
#
# Need to use the magic command: `%matplotlib`
#
# combined with either: notebook (interactive plots) or inline (static plots)

# %%
# %matplotlib notebook

# %%
import numpy as np
x = np.linspace(0, 10, 100)

fig = plt.figure()
plt.plot(x, np.sin(x), '-')
plt.plot(x, np.cos(x), '--');
# Out:
# <div id='8168ad4e-481d-4ea2-abf9-bbd6fd159a01'></div>

# %% [markdown]
# ## Saving Figures to File
#
# Can generally be done using the `savefig()` command.

# %%
fig.savefig('my_figure.png')

# %% [markdown]
# To confirm its contents, we can use IPython's `Image` object to display the contents of the file:

# %%
from IPython.display import Image
Image('my_figure.png')

# %%
fig.canvas.get_supported_filetypes()
# Out:
# {'eps': 'Encapsulated Postscript',
#  'jpg': 'Joint Photographic Experts Group',
#  'jpeg': 'Joint Photographic Experts Group',
#  'pdf': 'Portable Document Format',
#  'pgf': 'PGF code for LaTeX',
#  'png': 'Portable Network Graphics',
#  'ps': 'Postscript',
#  'raw': 'Raw RGBA bitmap',
#  'rgba': 'Raw RGBA bitmap',
#  'svg': 'Scalable Vector Graphics',
#  'svgz': 'Scalable Vector Graphics',
#  'tif': 'Tagged Image File Format',
#  'tiff': 'Tagged Image File Format'}

# %% [markdown]
# ## Two Interfaces for the Price of One
#
# 1. Matlab-style state-based interface
# 2. Object-oriented interface

# %% [markdown]
# ### MATLAB-style interface
#
# Matplotlib written as Python alternative for MATLAB users.
#
# MATLAB-style tools are contained in the pyplot (`plt`) interface:

# %%
plt.figure()  # create a plot figure

# create the first of two panels and set current axis
plt.subplot(2, 1, 1) # (rows, columns, panel number)
plt.plot(x, np.sin(x))

# create the second panel and set current axis
plt.subplot(2, 1, 2)
plt.plot(x, np.cos(x));
# Out:
# <div id='8e677924-2acc-4ef8-ac88-e075ee903565'></div>

# %%
plt.figure()  # create a plot figure

# create the first of two panels and set current axis
plt.subplot(1, 2, 1) # (rows, columns, panel number)
plt.plot(x, np.sin(x))

# create the second panel and set current axis
plt.subplot(2, 2, 3)
plt.plot(x, np.cos(x))

plt.subplot(2, 10, 3)
plt.plot(x, np.cos(x));
# Out:
# <div id='4c3c829f-30d7-4d7a-8f90-8805d24fbbf6'></div>

# %% [markdown]
# This is *stateful* and keeps track of the current figure and axes.
#
# `plt.gcf()`
#
# Difficult to go back to previous figures.

# %% [markdown]
# ### Object-oriented interface
#
# More complex but gives more control
#
# Plotting functions are *methods* of explicit `Figure` and `Axes` objects:

# %%
# First create a grid of plots
# ax will be an array of two Axes objects
fig, ax = plt.subplots(2)

# Call plot() method on the appropriate object
ax[0].plot(x, np.sin(x))
ax[1].plot(x, np.cos(x));
# Out:
# <div id='01621b76-40eb-4767-bbcb-e4e73d579686'></div>

# %% [markdown]
# ### Which one should you use?
#
# Convenience is the main driver.
#
# OO approach necessary as plots become more complex.
#
# We will switch between these interfaces throughout these lectures.
#
# Main difference is switching between `plt.plot()` and `ax.plot()`

# %% [markdown]
# # Simple Line Plots
#
# Simplest of all plots is the visualisation of a single function $y = f(x)$

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np

# %% [markdown]
# For all plots, start by creating a figure and axes:

# %%
fig = plt.figure()
ax = plt.axes()

# %% [markdown]
# `plt.Figure` can be thought ot as a single container for objects representing:
#
# - axes
# - graphics
# - text
# - labes

# %% [markdown]
# `plt.Axes` is what we see:
#
# - a bounding box with ticks and labels
# - eventually will contain our visualisation.

# %% [markdown]
# Commone formalism: `fig` refers to a rigure instance and `ax` referes to axes or group of axes.

# %% [markdown]
# Once we have created an axes, we can use the ax.plot function to plot some data. Let's start with a simple sinusoid:

# %%
fig = plt.figure()
ax = plt.axes()

x = np.linspace(0, 10, 1000)
ax.plot(x, np.sin(x));

# %% [markdown]
# Or, we can use the MATLAB style:

# %%
plt.plot(x, np.sin(x));

# %% [markdown]
# If we want to create a single figure with multiple lines, we can simply call the `plot` function multiple times

# %%
plt.plot(x, np.sin(x))
plt.plot(x, np.cos(x));

# %% [markdown]
# That's all there is to plotting in Matplotlib!

# %% [markdown]
# ## Adjusting the Plot: Line Colors and Styles
#
# The first adjustment you might wish to make to a plot is to control the line colors and styles.
#
# The `plt.plot()` function takes additional arguments that can be used to specify these.
#
# To adjust the color, you can use the `color` keyword, which accepts a string argument representing virtually any imaginable color.

# %%
plt.plot(x, np.sin(x - 0), color='blue')        # specify color by name
plt.plot(x, np.sin(x - 1), color='g')           # short color code (rgbcmyk)
plt.plot(x, np.sin(x - 2), color='0.75')        # Grayscale between 0 and 1
plt.plot(x, np.sin(x - 3), color='#FFDD44')     # Hex code (RRGGBB from 00 to FF)
plt.plot(x, np.sin(x - 4), color=(1.0,0.2,0.3)) # RGB tuple, values 0 to 1
plt.plot(x, np.sin(x - 5), color='chartreuse'); # all HTML color names supported

# %% [markdown]
# If no color is specified, Matplotlib will automatically cycle through a set of default colors for multiple lines.

# %% [markdown]
# Similarly, the line style can be adjusted using the linestyle keyword:

# %%
plt.plot(x, x + 0, linestyle='solid')
plt.plot(x, x + 1, linestyle='dashed')
plt.plot(x, x + 2, linestyle='dashdot')
plt.plot(x, x + 3, linestyle='dotted');

# For short, you can use the following codes:
plt.plot(x, x + 4, linestyle='-')  # solid
plt.plot(x, x + 5, linestyle='--') # dashed
plt.plot(x, x + 6, linestyle='-.') # dashdot
plt.plot(x, x + 7, linestyle=':');  # dotted

# %% [markdown]
# If you would like to be extremely terse, these linestyle and color codes can be combined into a single non-keyword argument to the `plt.plot()` function:

# %%
plt.plot(x, x + 0, '-g')  # solid green
plt.plot(x, x + 1, '--c') # dashed cyan
plt.plot(x, x + 2, '-.k') # dashdot black
plt.plot(x, x + 3, ':r');  # dotted red

# %% [markdown]
# These single-character color codes reflect the standard abbreviations in the RGB (Red/Green/Blue) and CMYK (Cyan/Magenta/Yellow/blacK) color systems, commonly used for digital color graphics.

# %% [markdown]
# # Adjusting the Plot: Axes Limits
#
# Matplotlib does a decent job of choosing default axes limits for your plot, but sometimes it's nice to have finer control.
#
# The most basic way to adjust axis limits is to use the `plt.xlim()` and `plt.ylim()` methods:

# %%
plt.plot(x, np.sin(x))

plt.xlim(-1, 11)
plt.ylim(-1.5, 1.5);

# %% [markdown]
# If for some reason you'd like either axis to be displayed in reverse, you can simply reverse the order of the arguments:

# %%
plt.plot(x, np.sin(x))

plt.xlim(10, 0)
plt.ylim(1.2, -1.2);

# %% [markdown]
# A useful related method is `plt.axis()`
#
# N.B here the potential confusion between *axes* with an *e*, and *axis* with an *i*).
#
# The `plt.axis()` method allows you to set the `x` and `y` limits with a single call, by passing a list which specifies `[xmin, xmax, ymin, ymax]`:

# %%
plt.plot(x, np.sin(x))
plt.axis([-1, 11, -1.5, 1.5]);

# %% [markdown]
# The `plt.axis()` allows you to do things like automatically tighten the bounds around the current plot, too:

# %%
plt.plot(x, np.sin(x))
plt.axis('tight');

# %% [markdown]
# Or an aspect ratio (one unit in `x` equals one unit in `y`:

# %%
plt.plot(x, np.sin(x))
plt.axis('equal');

# %% [markdown]
# ## Labelling Plots
#
# Let's lastly consider who to label plots with:
#
# - titles
# - axis labels
# - and simple legends.
#
# Labelling your plots is often overlooked but essential!

# %%
plt.plot(x, np.sin(x))
plt.title("A Sine Curve")
plt.xlabel("x")
plt.ylabel("sin(x)");

# %% [markdown]
# When multiple lines are being shown within a single axes, it can be useful to create a plot legend that labels each line type.
#
# Use a legend: `plt.legend()` method.
#
# Specify line of each label using label value:

# %%
plt.plot(x, np.sin(x), '-g', label='sin(x)')
plt.plot(x, np.cos(x), ':b', label='cos(x)')
plt.axis('equal')

plt.legend();

# %% [markdown]
# ## Matplotlib Gotchas
#
# Things like `.plot()` are equivalent.
#
# The following are subtle differences worth noting:
#
# `plt.xlabel() → ax.set_xlabel()
# plt.ylabel() → ax.set_ylabel()
# plt.xlim() → ax.set_xlim()
# plt.ylim() → ax.set_ylim()
# plt.title() → ax.set_title()`

# %% [markdown]
# In the object-oriented interface to plotting, rather than calling these functions individually, it is often more convenient to use the `ax.set()`method to set all these properties at once:

# %%
ax = plt.axes()
ax.plot(x, np.sin(x))
ax.set(xlim=(0, 10), ylim=(-2, 2),
       xlabel='x', ylabel='sin(x)',
       title='A Simple Plot');

# %% [markdown]
# # Simple Scatter Plots
#
# Another commonly used plot type is the simple scatter plot.
#
# Instead of points being joined by line segments, here the points are represented individually with a dot, circle, or other shape.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np

# %%
x = np.linspace(0, 10, 30)
y = np.sin(x)

plt.plot(x, y, 'o', color='black');

# %% [markdown]
# The third argument in the function call is a character that represents the type of symbol used for the plotting.
#
# The full list of available symbols can be seen in the documentation of plt.plot
#
# Most of the possibilities are fairly intuitive

# %%
rng = np.random.RandomState(0)
for marker in ['o', '.', ',', 'x', '+', 'v', '^', '<', '>', 's', 'd']:
    plt.plot(rng.rand(5), rng.rand(5), marker,
             label="marker='{0}'".format(marker))
plt.legend(numpoints=1)
plt.xlim(0, 1.8);

# %% [markdown]
# For even more possibilities, these character codes can be used together with line and color codes to plot points along with a line connecting them:

# %%
plt.plot(x, y, '-vg');

# %% [markdown]
# Additional keyword arguments to plt.plot specify a wide range of properties of the lines and markers:

# %%
plt.plot(x, y, '-p', color='gray',
         markersize=15, linewidth=4,
         markerfacecolor='white',
         markeredgecolor='red',
         markeredgewidth=2)
plt.ylim(-1.2, 1.2);

# %% [markdown]
# ## Scatter Plots with `plt.scatter`

# %%
plt.scatter(x, y, marker='o');

# %% [markdown]
# The primary difference of `plt.scatter` from `plt.plot` is that it can be used to create scatter plots where the properties of each individual point (size, face color, edge color, etc.) can be individually controlled or mapped to data.

# %%
rng = np.random.RandomState(0)
x = rng.randn(100)
y = rng.randn(100)
colors = rng.rand(100)
sizes = 1000 * rng.rand(100)

plt.scatter(x, y, c=colors, s=sizes, alpha=0.3,
            cmap='viridis')
plt.colorbar();  # show color scale
# Out:
# C:\Users\kris\AppData\Local\Temp\ipykernel_1664\970815911.py:9: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   plt.colorbar();  # show color scale

# %% [markdown]
# Notice that the color argument is automatically mapped to a color scale (shown here by the `colorbar()` command)
#
# The size argument is given in pixels.
#
# Colour and size of points can be used to convey information in the visualisation, in order to visualise multidimensional data.

# %% [markdown]
# For example, we might use the Iris data from Scikit-Learn, where each sample is one of three types of flowers that has had the size of its petals and sepals carefully measured:

# %%
from sklearn.datasets import load_iris
iris = load_iris()
features = iris.data.T

plt.scatter(features[0], features[1], alpha=0.2,
            s=100*features[3], c=iris.target, cmap='viridis')
plt.xlabel(iris.feature_names[0])
plt.ylabel(iris.feature_names[1]);

# %% [markdown]
# This scatter plot has given us the ability to simultaneously explore four different dimensions of the data:
#
# - the (x, y) location of each point corresponds to the sepal length and width
# - the size of the point is related to the petal width
# - the color is related to the particular species of flower.
#
# Multicolour and multifeature scatter plots like this can be useful for both exploration and presentation of data.

# %% [markdown]
# # Summary
#
# This lecture has gone over the basics of plotting with Matplotlib:
#
# Key things to note:
#
# - two different interfaces
# - two different approaches to plotting
# - Lots of customisation options, consult documentation for even more!
